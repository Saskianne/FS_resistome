# %% [markdown]
# # Bioinformatic analysis for Nanopore 16S Amplicon Sequencing

# %%
# set up the conda environment named DORADO 1.1.1
    conda create -n DORADO_1.1.1
    conda activate DORADO_1.1.1
    cd /gxfs_work/geomar/smomw681/DORADO
    wget -r "https://cdn.oxfordnanoportal.com/software/analysis/dorado-1.1.1-linux-x64.tar.gz"
    tar -xzvf dorado-1.1.1-linux-x64.tar.gz
    dorado-1.1.1-linux-x64/bin/dorado --version
    echo 'export PATH="/gxfs_work/geomar/smomw681/DORADO/dorado-1.1.1-linux-x64/bin:$PATH"' >> ~/.bashrc
    source ~/.bashrc

# Download the model required
wget -O /gxfs_work/geomar/smomw681/DORADO/dna_r10.4.1_e8.2_400bps_hac@v5.2.0.zip -r "https://cdn.oxfordnanoportal.com/software/analysis/dorado/dna_r10.4.1_e8.2_400bps_hac@v5.2.0.zip" 
unzip /gxfs_work/geomar/smomw681/DORADO/dna_r10.4.1_e8.2_400bps_hac@v5.2.0.zip
